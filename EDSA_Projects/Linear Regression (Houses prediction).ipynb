# %% [markdown]
# ### Importing  the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Loading the data

# %%
data = pd.read_csv('https://raw.githubusercontent.com/DrSaadLa/MLLabs/main/data/housing.csv')
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
# the correlation between the features and the target value
data.corr().T['Price']
# Out:
# Avg. Area Income                0.639734
# Avg. Area House Age             0.452543
# Avg. Area Number of Rooms       0.335664
# Avg. Area Number of Bedrooms    0.171071
# Area Population                 0.408556
# Price                           1.000000
# Name: Price, dtype: float64

# %% [markdown]
# ### Some Visualization

# %%
sns.set(rc={'figure.figsize': [8, 8]}, font_scale=1.2)

# %%
sns.pairplot(data)

# %%
sns.displot(data['Price'], kde=True)

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# **Data Cleaning or Cleansing**

# %%
data.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
# Avg. Area Number of Bedrooms have low correlation with house's price 
data.drop('Avg. Area Number of Rooms',axis=1,inplace=True)

# %%
# dropping 'Adress' column
data.drop('Address',axis=1,inplace=True)

# %%
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Bedrooms  \
# 0      79545.458574             5.682861                          4.09
# 1      79248.642455             6.002900                          3.09
# 2      61287.067179             5.865890                          5.13
# 3      63345.240046             7.188236                          3.26
# 4      59982.197226             5.040555                          4.23
#
#    Area Population         Price
# 0     23086.800503  1.059034e+06
# 1     40173.072174  1.505891e+06
# 2     36882.159400  1.058988e+06
# 3     34310.242831  1.260617e+06
# 4     26354.109472  6.309435e+05

# %%
X = data.drop('Price',axis=1)

# %%
X.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Bedrooms  \
# 0      79545.458574             5.682861                          4.09
# 1      79248.642455             6.002900                          3.09
# 2      61287.067179             5.865890                          5.13
# 3      63345.240046             7.188236                          3.26
# 4      59982.197226             5.040555                          4.23
#
#    Area Population
# 0     23086.800503
# 1     40173.072174
# 2     36882.159400
# 3     34310.242831
# 4     26354.109472

# %%
X.shape
# Out:
# (5000, 4)

# %%
y=data['Price']

# %%
y.shape
# Out:
# (5000,)

# %% [markdown]
# **Splitting the data to train and test sets**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.20,random_state=0)

# %%
X_train.shape
# Out:
# (4000, 4)

# %%
X_test.shape
# Out:
# (1000, 4)

# %%
y_train.shape
# Out:
# (4000,)

# %%
y_test.shape
# Out:
# (1000,)

# %% [markdown]
# ### Training the model 'Regression'

# %%
from sklearn.linear_model import LinearRegression

# %%
ln_reg=LinearRegression()

# %%
ln_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
ln_reg.score(X_train,y_train)
# Out:
# 0.8258927445453846

# %%
y_pred = ln_reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error,r2_score

# %%
print('R2_score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
print('RMSE',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2_score 0.8226741144030396
# MAE 117746.0512484511
# MSE 21917270398.132233
# RMSE 148044.825637819

# %%
sns.displot(y_test-y_pred,kde=True) # plotting the error between the acual data and predicted data

# %% [markdown]
# **changing the test size to 10%**

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.10,random_state=0)

# %%
X_train.shape
# Out:
# (4500, 4)

# %%
X_test.shape
# Out:
# (500, 4)

# %%
y_train.shape
# Out:
# (4500,)

# %%
y_test.shape
# Out:
# (500,)

# %%
ln_reg=LinearRegression()

# %%
ln_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
ln_reg.score(X_train,y_train)
# Out:
# 0.8237930802979396

# %%
y_pred = ln_reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error,r2_score

# %%
print('R2_score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
print('RMSE',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2_score 0.8378061262841922
# MAE 115187.65383320086
# MSE 21053280243.07332
# RMSE 145097.48530926826

# %%
sns.displot(y_test-y_pred,kde=True)

# %% [markdown]
# **Using cross validation**

# %%
from sklearn.model_selection import cross_val_score

# %%
ln_reg_cv=LinearRegression()

# %%
crs_val=cross_val_score(ln_reg_cv,X,y,cv=5)

# %%
crs_val
# Out:
# array([0.81950446, 0.84212266, 0.8177484 , 0.82166025, 0.82021533])

# %%
crs_val.mean()
# Out:
# 0.8242502214337029

# %% [markdown]
# ### Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.10,random_state=0)

# %%
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.fit_transform(X_test)

# %%
poly_reg=LinearRegression()

# %%
poly_reg.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
y_pred=poly_reg.predict(X_test_poly)

# %%
print('R2_score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
print('RMSE',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2_score 0.8373919828561175
# MAE 115094.12046245736
# MSE 21107037376.140877
# RMSE 145282.61209153998

# %%
sns.displot(y_test-y_pred,kde=True)

# %% [markdown]
# ### Scalling the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(X)
# Out:
# array([[ 1.02865969, -0.29692705,  0.08806222, -1.31759867],
#        [ 1.00080775,  0.02590164, -0.72230146,  0.40399945],
#        [-0.68462916, -0.11230283,  0.93084045,  0.07240989],
#        ...,
#        [-0.48723454,  1.28447022, -1.50025059, -0.29193658],
#        [-0.05459152, -0.44669439,  1.18205319,  0.65111608],
#        [-0.28831272,  0.01521477,  0.07185495,  1.04162464]])

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.10,random_state=0)

# %%
ln_reg_sc=LinearRegression()

# %%
ln_reg_sc.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = ln_reg_sc.predict(X_test)

# %%
print('R2_score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
print('RMSE',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2_score 0.8378061262841922
# MAE 115187.65383320086
# MSE 21053280243.07332
# RMSE 145097.48530926826
